# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **Algoritma dan Pemrograman**
#
# **“Statement Condisional”**
#
# **Disusun Oleh :**
#
# **Raga Mohammad Aidil Fitra**
#
# **2611532002**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Muhammad Galid Avero**
#
# <br>
#
#  <img src="data:image/png;base64,..." width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji dan syukur penulis ucapkan ke hadirat Tuhan Yang Maha Esa atas segala rahmat dan karunia-Nya, sehingga laporan praktikum Algoritma dan Pemrograman untuk pertemuan ke-4 ini dapat diselesaikan dengan baik. Materi yang dibahas pada praktikum kali ini adalah Statement Kondisional, yang mencakup if, elif (Else-If), else, dan Match-case.
#
# Penyusunan laporan ini bertujuan agar penulis dapat lebih memahami serta mempraktikkan secara langsung bagaimana statement kondisional bekerja dan apa manfaatnya dalam penyelesaian permasalahan pemrograman.
#
#
# Penulis menyadari laporan ini masih jauh dari sempurna dan tentu memiliki keterbatasan. Untuk itu, masukan berupa kritik maupun saran sangat penulis harapkan guna penyempurnaan laporan pada kesempatan berikutnya.
#
# Padang, 2026
# <br>
# <br>
# <br>
# <br>
# Raga Mohammad Aidil Fitra,<br>2611532002

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Di dalam aktivitas sehari-hari, setiap orang senantiasa dihadapkan pada pengambilan keputusan berdasarkan suatu kondisi, contohnya memilih membawa jas hujan apabila cuaca mendung. Prinsip berpikir semacam ini juga diperlukan dalam dunia pemrograman, agar suatu program tidak sekadar dijalankan secara berurutan dari awal sampai akhir, melainkan mampu menyesuaikan tindakannya dengan data yang sedang diolah. Kemampuan tersebut diakomodasi melalui statement kondisional atau struktur percabangan, yakni instruksi yang mengevaluasi suatu kondisi menjadi benar (True) atau salah (False), kemudian menjalankan blok instruksi yang sesuai dengan hasil evaluasi itu.
#
# Statement kondisional termasuk salah satu dari tiga struktur dasar dalam algoritma, selain struktur runtunan (sekuensial) dan struktur pengulangan (iterasi). Memahami konsep ini menjadi hal mendasar sebab hampir semua program yang digunakan secara nyata, seperti proses validasi data masukan, penentuan predikat kelulusan, hingga tampilan menu pilihan, tidak lepas dari proses pengambilan keputusan.
#
# Di dalam bahasa pemrograman Python, percabangan dapat diterapkan dalam beberapa bentuk pernyataan. Pernyataan if berfungsi menjalankan suatu blok kode apabila syarat yang ditentukan terpenuhi. Sementara itu, else berperan sebagai jalur cadangan yang dieksekusi bila kondisi pada if tidak tercapai, sedangkan elif memungkinkan beberapa kondisi diperiksa secara bertahap sehingga program mampu menangani lebih dari dua kemungkinan keluaran. Di samping itu, mulai Python versi 3.10 diperkenalkan pernyataan match-case, yang mencocokkan suatu nilai dengan sejumlah pola tertentu sehingga percabangan bertingkat banyak dapat ditulis lebih ringkas dibandingkan rangkaian if-elif-else yang panjang. Selain itu, Python juga mewajibkan penulisan indentasi yang rapi pada tiap blok kode, sehingga kedisiplinan dalam penulisan struktur kode menjadi hal yang tidak boleh diabaikan.
#
# Kendati konsepnya tampak mudah, tidak sedikit pemula yang masih kesulitan memahami logika pemrograman, khususnya dalam merumuskan kondisi yang benar, menggunakan operator relasional maupun logika secara tepat, mengurutkan pemeriksaan pada elif, serta menentukan kapan lebih cocok memakai if-elif-else dibandingkan match-case. Sekecil apa pun kesalahan dalam merumuskan kondisi dapat menyebabkan keluaran program menjadi tidak sesuai harapan, meskipun secara sintaks program tetap dapat dijalankan. Oleh sebab itu, pemahaman terhadap algoritma percabangan perlu diasah lewat latihan praktik secara langsung, bukan hanya lewat teori semata.
#
# Atas dasar pertimbangan tersebut, praktikum ini dilaksanakan supaya praktikan dapat memahami konsep serta perbedaan penerapan if, elif, else, dan match-case, menuangkan suatu permasalahan ke dalam alur logika, lalu mengimplementasikannya menggunakan bahasa Python. Melalui praktikum ini, praktikan diharapkan mampu merancang program yang mengambil keputusan secara tepat sekaligus memiliki bekal yang memadai untuk mempelajari materi lanjutan, seperti perulangan dan fungsi.
#
#
# ## 1.2 Tujuan
# 1. Praktikan memahami konsep dan cara kerja statement kondisional (if, elif, else, dan match-case) dalam bahasa pemrograman Python.
# 2. Praktikan mampu menerjemahkan suatu permasalahan ke dalam alur logika percabangan sebelum menuliskannya sebagai kode program.
# 3. Praktikan mampu mengimplementasikan dan menguji program yang menggunakan struktur percabangan untuk menghasilkan keluaran yang sesuai dengan kondisi yang diberikan.
# ## 1.3 Manfaat
# 1. Bagi Pelajar: Praktikum ini memberi bekal keterampilan menyusun logika percabangan yang dibutuhkan untuk menyelesaikan persoalan pemrograman yang lebih kompleks, seperti validasi data dan pengambilan keputusan bertingkat.
# 2. Bagi pengajar/Dosen: Hasil praktikum ini menjadi bahan evaluasi untuk mengukur sejauh mana mahasiswa memahami struktur kontrol percabangan, sekaligus dasar untuk menentukan materi lanjutan yang perlu diperkuat.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# Berikut ini merupakan penjelasan mengenai dasar teori yang digunakan untuk praktikum ini :
#
# Statement Kondisional (percabangan) merupakan instruksi yang menilai suatu ekspresi hingga menghasilkan nilai boolean, True atau False, kemudian menjalankan blok kode tertentu sesuai hasil penilaian tersebut. Dengan struktur ini, program dapat mengambil keputusan dan berpindah ke alur yang berbeda-beda menyesuaikan data yang sedang diproses, bukan sekadar menjalankan instruksi secara berurutan saja. Beberapa bentuk pernyataan yang tercakup dalam statement kondisional adalah sebagai berikut:
#
# a. Pernyataan if: merupakan bentuk percabangan yang paling dasar. Blok kode pada if baru dieksekusi apabila kondisi yang diperiksa bernilai True; sebaliknya, jika bernilai False, blok tersebut akan dilewati begitu saja.
#         <br>
# b. Pernyataan if-else: kehadiran else memberikan jalur alternatif yang akan dieksekusi manakala kondisi pada if tidak terpenuhi (False). Dengan demikian, salah satu dari dua blok kode yang tersedia pasti akan dijalankan.
# <br>
# c. Pernyataan elif: merupakan singkatan dari else if, dipakai untuk memeriksa kondisi tambahan secara berurutan apabila kondisi sebelumnya bernilai False. Melalui struktur ini, program sanggup menangani lebih dari sekadar dua kemungkinan hasil dalam satu rangkaian percabangan.
# <br>
# d. Pernyataan match-case: mulai diperkenalkan pada Python 3.10 sebagai wujud dari structural pattern matching. Pernyataan ini mencocokkan suatu nilai (subject) terhadap beberapa pola (pattern) yang telah ditetapkan pada masing-masing blok case, lalu menjalankan blok yang polanya paling pertama cocok. Penggunaan match-case lebih sesuai ketika suatu nilai perlu dibandingkan dengan banyak kemungkinan yang sifatnya diskret, karena penulisannya lebih singkat dan lebih mudah dibaca dibandingkan rangkaian if-elif-else yang panjang.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program If "if1_2611532002"
# Berikut ini merupakan program If yang dijalankan melalui Visual Studio Code dengan bahasa pemrograman python:

# %%
# Buat file dengan nama if1_NIM.py
# Buat program untuk kondisional if
# Nama variabel ditambah 4 digit nim terakhir contoh : ipk_1234
# Program ini menggunakan fungsi input()

ipk_2002 = float(input("Input IPK anda: "))

if ipk_2002 > 2.75:
    print("Anda Lulus Sangat Memuaskan dengan IPK " + str(ipk_2002))

print("Program Selesai")
# Out:
# Anda Lulus Sangat Memuaskan dengan IPK 3.4
# Program Selesai

# %% [markdown]
# **Penjelasan :**
# - Baris `#` → komentar, tidak dieksekusi; berisi nama file, tujuan program, dan aturan penamaan variabel.
# - `ipk_2002 = float(input("Input IPK anda: "))` → menerima input IPK sebagai string, dikonversi ke bilangan pecahan (`float`), disimpan ke `ipk_2002`.
# - `if ipk_2002 > 2.75:` → mengecek apakah IPK lebih besar dari 2.75. Tidak ada `else` di program ini.
# - `print("Anda Lulus Sangat Memuaskan dengan IPK " + str(ipk_2002))` → dijalankan **hanya jika** kondisi `True`. `str(ipk_2002)` mengonversi angka menjadi string agar bisa digabung (`+`) dengan teks.
# - `print("Program Selesai")` → dijalankan **selalu**, karena berada di luar blok `if` (tidak diindentasi ke dalam).

# %%
# Buat file dengan nama if2_NIM.py
# Buat program untuk kondisional if 
# Nama variabel ditambah dengan 4 digit NIM terakhir contoh: ipk_1234
#  Program ini menggunakan fungsi input()

ipk_2002 = float(input("Input IPK Anda = "))

if ipk_2002>2.75:
    print("Anda Lulus dengan Sangat Memuaskan IPK " + str(ipk_2002))
else:
    print("Anda Tidak Lulus")
print("Program Selesai")
# Out:
# Anda Lulus dengan Sangat Memuaskan IPK 3.0
# Program Selesai

# %% [markdown]
# **Penjelasan:**
# - Baris `#` → komentar, sama fungsinya seperti sebelumnya.
# - `ipk_2002 = float(input("Input IPK Anda = "))` → menerima dan mengonversi input IPK ke `float`.
# - `if ipk_2002 > 2.75:` → mengecek kondisi IPK.
# - `print("Anda Lulus dengan Sangat Memuaskan IPK " + str(ipk_2002))` → dijalankan jika `True`.
# - `else: print("Anda Tidak Lulus")` → dijalankan jika `False` (IPK ≤ 2.75).
# - `print("Program Selesai")` → selalu dijalankan setelah blok `if-else`, apa pun hasilnya.

# %% [markdown]
# ### 2.2.3 Program Multi If "multi_if1_2611532002"
# Berikut ini merupakan program Multi If yang dijalankan melalui Visual Studio Code dengan bahasa pemrograman python:

# %%
# Buat file dengan nama multi_if1_NIM.py
# Buat program untuk kondisioanl if 
# Nama variabel ditambah 4 digit NIM terakhir contoh: ipk_1234
# Program ini menggunakan fungsi input()

umur_2002 = int(input("Input umur anda: "))
sim_2002 = input("Apakah Anda Sudah Punya SIM C(y/t): ")[0]

if umur_2002 >= 17 and sim_2002 == 'y':
    print("Anda Sudah Dewasa dan Boleh Membawa Motor")

if umur_2002 >= 17 and sim_2002 != 'y':
    print("Anda Sudah dewasa tetapi tidak boleh membawa motor")
    
if umur_2002 < 17 and sim_2002 == 'y':
    print("Anda Belum cukup umur punya SIM")

if umur_2002 < 17 and sim_2002 != 'y':
    print("Anda Belum Cukup Umur bawa motor")
# Out:
# Anda Sudah Dewasa dan Boleh Membawa Motor

# %% [markdown]
# **Penjelasan:**
# - `umur_2002` dan `sim_2002` diterima dan diproses sama seperti program #3.
# - Empat blok `if` **berdiri sendiri** , masing-masing mengecek kombinasi umur (≥17/<17) dan SIM (==/!= 'y').
# - Karena keempat kondisi saling eksklusif, tepat satu blok yang `True` untuk tiap kombinasi input — hasil akhirnya sama.
#
# **Perbedaan dari `if-elif-else`:** Python di sini **tetap mengecek semua 4 kondisi** satu per satu meski kondisi pertama sudah `True`, sedangkan `if-elif-else` langsung berhenti begitu satu kondisi cocok.

# %% [markdown]
# ### 2.2.4 Program Multi If "multi_if2_2611532002"
# Berikut ini merupakan program Multi If yang dijalankan melalui Visual Studio Code dengan bahasa pemrograman python:

# %%
# Buat file dengan nama multi_if2_nim.py
# Buat program untuk kondisional if 
# Nama variabel ditambah 4 digit nim terakhir contoh: total_belanja_2002
# Program ini menggunakan fungsi input()
# Program menghitung diskon belanja

# Input dari user
total_belanja_2002 = float(input("Masukkan total belanja(Rp): "))

# Input status member (mengecek apakah user mengetik 'y' atau "ya")
input_member_2002 = input("Apakah Anda member? (y/t): ")
is_member_2002 = input_member_2002 in ["y", "ya"]

#Input status kode promo (mengecek apakah user mengetik 'y' atau "ya")
input_promo_2002 = input("Apakah kode promo valid (y/t): ") .strip().lower()
kode_promo_valid_2002 = input_promo_2002 in ['y',"ya"]

total_diskon_persen_2002 = 0

# Multi-If terpisah: Setiap kondisi diperiksa secara independen 
# Diskon bisa ditumpuk (akumulasi) jika memenuhi beberapa syarat sekaligus

if total_belanja_2002 > 1000000:
    total_diskon_persen_2002 += 10 # Diskon belanja besar

if is_member_2002:
    total_diskon_persen_2002 += 5 # Diskon member

if kode_promo_valid_2002:
    total_diskon_persen_2002 += 15 # Diskon voucher
    
# Menghitung nominal diskon dan total  bayar
nominal_diskon_2002 = total_belanja_2002*(total_diskon_persen_2002 / 100)
total_bayar_2002 = total_belanja_2002 - nominal_diskon_2002

# Output hasil
print("\n --- Rincian Pembayaran---")
print(f"Total Diskon : {total_diskon_persen_2002}% (Rp {nominal_diskon_2002 :,.0f})")
print(f"Total Bayar : Rp {total_bayar_2002 :,.0f}")

print(f"Total diskon yang Anda dapatkan: {total_diskon_persen_2002}%")
#Output : Total diskon yang Anda dapatkan: 30% jika belanja > 1 juta, member, dan kode promo valid
# Out:
#  --- Rincian Pembayaran---
# Total Diskon : 20% (Rp 10,000)
# Total Bayar : Rp 40,000
# Total diskon yang Anda dapatkan: 20%

# %% [markdown]
# **Penjelasan:**
# - `total_belanja_2002 = float(input(...))` → menerima total belanja sebagai `float`.
# - `input_member_2002 = input(...)` → menyimpan jawaban member mentah.
# - `is_member_2002 = input_member_2002 in ["y", "ya"]` → boolean status member.
# - `input_promo_2002 = input(...).strip().lower()` → dibersihkan spasi dan huruf kecil.
# - `kode_promo_valid_2002 = input_promo_2002 in ['y', "ya"]` → boolean status promo.
# - `total_diskon_persen_2002 = 0` → akumulator, nilai awal 0.
# - Tiga blok `if` **independen** — belanja > 1.000.000 (+10%), member (+5%), promo valid (+15%) — semuanya dicek terpisah sehingga diskon bisa **menumpuk** hingga 30%.
# - `nominal_diskon_2002` dan `total_bayar_2002` → dihitung dari total persentase yang terkumpul.

# %% [markdown]
# **Berikut ini adalah Output dari Program Operator Bitwise yang dijalankan menggunanakan terminal:**
#
# <div align="center">
# <img src="image/output_bitwise.png" width="500"><br>
# <em>Gambar 2.4 : Output Bitwise</em>
# </div>

# %% [markdown]
# ### 2.2.5 Program Elif "nilai_2611532002"
# Berikut ini merupakan program Elif yang dijalankan melalui Visual Studio Code dengan bahasa pemrograman python:

# %%
# Buat file dengan nama nilai_nim.py
# Buat program untuk kodisional if
# Nama variabel ditambah 4 digit terakhir contoh: ipk_1234
# Program ini menggunakan fungsi input()
# Program konversi nilai angka menjadi huruf

nilai_2002 = int(input("Inputkan nilai angka = "))

if nilai_2002 >= 81:
     print('A')
     
elif nilai_2002 >= 70:
    print("B")
elif nilai_2002:
    print('C')
else:
    print("E")
# Out:
# A

# %% [markdown]
# **Penjelasan:**
# - `nilai_2002 = int(input(...))` → menerima nilai angka sebagai integer.
# - `if nilai_2002 >= 81: print('A')` → nilai ≥ 81 → grade A.
# - `elif nilai_2002 >= 70: print("B")` → dicek jika kondisi pertama gagal; nilai ≥ 70 → grade B.
# - `elif nilai_2002: print('C')` → **bukan perbandingan angka**, melainkan uji *truthy* — bernilai `True` untuk semua angka bukan-nol.
# - `else: print("E")` → hanya tercapai jika `nilai_2002` persis **0**.

# %% [markdown]
# ### 2.2.6 Program If Elif Else "if_elif_else1_2611532002"
# Berikut ini merupakan program If Elif Else yang dijalankan melalui Visual Studio Code dengan bahasa pemrograman python:

# %%
# Buat file dengan nama if_elif_else_nim.py
# Buat program untuk kondisional if
# Nama variabel ditambah 4 digit nim terakhir contoh: ipk_1234
# Program ini menggunakan fungsi input()

umur_2002 =  int(input("Input umur Anda: "))
sim_2002 = input("Apaakh Anda sudah punya SIM C: ")[0]

if umur_2002 >= 17 and sim_2002 == 'y':
    print("Anda Sudah Dewasa dan Boleh Membawa Motor")

elif umur_2002>= 17 and sim_2002 != 'y':
    print("Anda Sudah dewasa tetapi tidak boleh membawa motor")
    
elif umur_2002< 17 and sim_2002 == 'y':
    print("Anda Belum cukup umur punya SIM")

else:
    print("Anda Belum Cukup umur dan tidak boleh bawa motor")

print("Program Selesai")
# Out:
# Anda Sudah Dewasa dan Boleh Membawa Motor
# Program Selesai

# %% [markdown]
# **Penjelasan:**
# - `umur_2002 = int(input(...))` → menerima umur sebagai integer.
# - `sim_2002 = input(...)[0]` → menerima jawaban kepemilikan SIM, diambil karakter pertamanya saja.
# - `if umur_2002 >= 17 and sim_2002 == 'y':` → dewasa **dan** punya SIM → boleh bawa motor.
# - `elif umur_2002 >= 17 and sim_2002 != 'y':` → dicek jika kondisi pertama gagal. Dewasa tapi **tidak** punya SIM.
# - `elif umur_2002 < 17 and sim_2002 == 'y':` → dicek jika dua kondisi sebelumnya gagal. Belum dewasa tapi mengaku punya SIM.
# - `else:` → sisa kasus: belum dewasa dan tidak punya SIM.
# - `print("Program Selesai")` → dijalankan di luar blok, selalu tercetak.

# %% [markdown]
# ### 2.2.7 Program Match-Case "match_case_2611532002"
# Berikut ini merupakan program Match-Case yang dijalankan melalui Visual Studio Code dengan bahasa pemrograman python:

# %%
# Buat file dengan nama case1.py
# Buat program untuk kodisional if
# Nama variabel ditambah 4 digit terakhir contoh: ipk_1234
# Program ini menggunakan fungsi input()
# Program konversi angka menjadi nama bulan

bulan_2002 = int(input("Masukkan angka bulan(1-12): "))

match bulan_2002:
    case 1:
        print("Januari")
    case 2:
        print("Februari")
    case 3:
        print("Maret")
    case 4:
        print("April")
    case 5:
        print("Mei")
    case 6:
        print("Juni")
    case 7:
        print("Juli")
    case 8: 
        print("Agustus")
    case 9:
        print("September")
    case 10:
        print("Oktober")
    case 11:
        print("November")
    case 12:
        print("Desember")
    case _:
        print("Angka Tidak Valid")
# Out:
# Januari

# %% [markdown]
# **Penjelasan:**
# 1. Baris # → komentar, tidak dieksekusi; berisi nama file, tujuan program, dan aturan penamaan variabel.
# 2. `bulan_2002 = int(input("Masukkan angka bulan(1-12): "))`:
#     -`input(...)` menampilkan teks dan menerima input pengguna sebagai string.
#     -`int(...)` mengonversi input tersebut menjadi bilangan bulat.
#     -Hasilnya disimpan ke variabel bulan_2002.
# 3. `match bulan_2002:` → memulai pencocokan nilai bulan_2002 dengan pola-pola case di bawahnya.
# 4. `case 1: s.d. case 12:` → jika bulan_2002 cocok dengan angka tersebut, jalankan print(...) nama bulan yang sesuai (1 = Januari, 2 = Februari, dst. sampai 12 = Desember).
# 5. `case _:` → wildcard, dijalankan jika bulan_2002 tidak cocok dengan case mana pun (di luar 1–12).
# 6. `print("Angka Tidak Valid")` → menampilkan pesan bahwa input tidak valid.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Dari rangkaian praktikum yang sudah dikerjakan, dapat ditarik kesimpulan bahwa statement kondisional (`if`, `elif`, `else`, dan `match-case`) memberi kemampuan bagi program untuk memilih alur eksekusi yang berbeda-beda menyesuaikan kondisi yang diuji, bukan sekadar menjalankan instruksi secara berurutan dari atas ke bawah. Penerapan pada program konversi bulan, konversi nilai, kelayakan berkendara motor, serta perhitungan diskon belanja memperlihatkan bahwa pemilihan struktur percabangan—baik `if` tunggal, `if-else`, `if-elif-else`, beberapa `if` independen, maupun `match-case`—sangat bergantung pada karakteristik persoalan yang dihadapi: apakah sifatnya eksklusif (hanya satu blok yang diperbolehkan berjalan) ataukah kumulatif (beberapa blok dapat berjalan sekaligus), serta apakah nilai yang diperiksa berupa kategori diskret atau berupa rentang angka.
#
# Pada praktiknya di bahasa Python, konsep ini mengandalkan evaluasi kondisi menjadi nilai boolean (`True`/`False`) yang dipadukan dengan operator relasional maupun logika (`>`, `>=`, `==`, `and`, `or`), sehingga program mampu menerjemahkan aturan-aturan di dunia nyata—seperti batas usia, ambang nilai IPK, ataupun status keanggotaan—ke dalam alur eksekusi yang sesuai. Praktikum ini pun memperlihatkan bahwa kekeliruan sekecil apa pun dalam menuliskan kondisi, misalnya kondisi yang kurang lengkap (`elif nilai_2002:` tanpa disertai operator pembanding) atau penggunaan `if` independen pada kasus yang seharusnya memakai `elif`, tetap dapat membuat keluaran program menjadi tidak sesuai, walaupun secara sintaks program tersebut berjalan tanpa error.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Isroqmi, A. (2017). Kemampuan Mahasiswa Memahami Logika Pemrograman Komputer Melalui Algoritma. Nabla Dewantara, 2(2), 59–74. https://ejournal.unitaspalembang.ac.id/index.php/nabla/article/view/512
#
# [2] Bangkit Sutowiyono "Pengenalan Dasar Algoritma Pemograman Bagi Mahasiswa", Journal of Informatics and Business, Vol. 01 No. 03, Oktober–Desember 2023, hlm. 156–161. https://jurnalmahasiswa.com/index.php/appa
